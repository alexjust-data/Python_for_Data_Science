# %% [markdown]
# # Estracción información en Twiter

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (3.10.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from tweepy) (2.24.0)
# Requirement already satisfied: six>=1.10.0 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/alexjust/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import json          #esta librería es para que se vea mejor


API_key = "orFJZZZuuj2BZsq830yjO7qUy"
API_key_secret = "12t7UqI5uS64t1mtrc4OPmYjfZEdoNordq8W4OBM7I4WHi4Iuk"
Access_token = "1329847802965467142-5MxSBM4CUJ2917bTLWCdkf9X9o3mfk"
Access_token_secret = "W8fcpCUqwZv7PnmdNpA6dy1PKZFxLAUWWdQrbk1DUHx8C"

#creo objeto
auth = tweepy.OAuthHandler(API_key, API_key_secret)

#del objeto auth llamo al método set_acces_token y le paso los acces
auth.set_access_token(Access_token, Access_token_secret)

#instancio el objeto de la clase API (este objeto será a través del cual iré realizando todas las llamadas al api de twitter)
api = tweepy.API(auth, wait_on_rate_limit = True,      #estos dos parametros me dicen que si se acaba el cupo
                 wait_on_rate_limit_notify = True,) #por el hecho de llegar a mis rate limits, el progrma no se cae
                                                   #esparará un cierto tiempo y cuando pueda continuará la descarga

# %%
#VOY A OPTENER INFORMACIÓN DE MI USUARIO TWITTER:
#utilizamos el objeto donde tenemos el api con método .me()
data = api.me()
print(data)
print("------")
print("He obtenido un objeto tipo USER que va a representar a todos los usuarios a través de la red social.")
print("------")
print("Aplico json para verlo mejor: ")
#dumps ha de recibir un diccionario ( o un json) no un objeto, pero titter para todos los objetos que nos devuelve
#la api de tweepy tiene un atributo ._json para obtener el json de los datos que he optenido
print(json.dumps(data._json, indent=2))
# Out:
# User(_api=<tweepy.api.API object at 0x7fc3dbb5ab20>, _json={'id': 1329847802965467142, 'id_str': '1329847802965467142', 'name': 'Alex', 'screen_name': 'Alex11421934', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Fri Nov 20 18:04:49 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Fri Nov 20 18:19:25 +0000 2020', 'id': 1329851858643537925, 'id_str': '1329851858643537925', 'text': 'hello world', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [], 'suspended': False, 'needs_phone_verification': False}, id=1329847802965467142, id_str='1329847802965467142', name='Alex', screen_name='Alex11421934', location='', profile_location=None, description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=0, friends_count=0, listed_count=0, created_at=datetime.datetime(2020, 11, 20, 18, 4, 49), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=1, lang=None, status=Status(_api=<tweepy.api.API object at 0x7fc3dbb5ab20>, _json={'created_at': 'Fri Nov 20 18:19:25 +0000 2020', 'id': 1329851858643537925, 'id_str': '1329851858643537925', 'text': 'hello world', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 11, 20, 18, 19, 25), id=1329851858643537925, id_str='1329851858643537925', text='hello world', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=0, favorite_count=0, favorited=False, retweeted=False, lang='en'), contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_b ...
# ------
# He obtenido un objeto tipo USER que va a representar a todos los usuarios a través de la red social.
# ------
# Aplico json para verlo mejor:
# {
#   "id": 1329847802965467142,
#   "id_str": "1329847802965467142",
#   "name": "Alex",
#   "screen_name": "Alex11421934",
#   "location": "",
#   "profile_location": null,
#   "description": "",
#   "url": null,
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "protected": false,
#   "followers_count": 0,
#   "friends_count": 0,
#   "listed_count": 0,
#   "created_at": "Fri Nov 20 18:04:49 +0000 2020",
#   "favourites_count": 0,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 1,
#   "lang": null,
#   "status": {
#     "created_at": "Fri Nov 20 18:19:25 +0000 2020",
#     "id": 1329851858643537925,
#     "id_str": "1329851858643537925",
#     "text": "hello world",
#     "truncated": false,
#     "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [],
#       "urls": []
#     },
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": true,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none",
#   "withheld_in_countries": [],
#   "suspended": false,
#   "needs_phone_verification": false
# }

# %%
#VOY A OBTENER INFO DE OTRO USUARIO
#utilizo el método .get_user()
data = api.get_user("nike")
print("\nCuenta de NIKE:")
print(json.dumps(data._json, indent=2))
# Out:
# Cuenta de NIKE:
# {
#   "id": 415859364,
#   "id_str": "415859364",
#   "name": "Nike",
#   "screen_name": "Nike",
#   "location": "Beaverton, Oregon",
#   "profile_location": null,
#   "description": "#BlackLivesMatter",
#   "url": "https://t.co/RBhnlkkzPV",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "https://t.co/RBhnlkkzPV",
#           "expanded_url": "http://nike.com",
#           "display_url": "nike.com",
#           "indices": [
#             0,
#             23
#           ]
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "protected": false,
#   "followers_count": 8326747,
#   "friends_count": 116,
#   "listed_count": 10701,
#   "created_at": "Fri Nov 18 22:31:18 +0000 2011",
#   "favourites_count": 6984,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": true,
#   "statuses_count": 36906,
#   "lang": null,
#   "status": {
#     "created_at": "Mon Nov 30 12:02:55 +0000 2020",
#     "id": 1333380991105310720,
#     "id_str": "1333380991105310720",
#     "text": "@OVANASIL \u00a1Hola de nuevo! \u00a1Puedes borrar el email con tu correo electr\u00f3nico y mand\u00e1rmelo por privado? Saludos.",
#     "truncated": false,
#     "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#         {
#           "screen_name": "OVANASIL",
#           "name": "SILVIA LACUEVA",
#           "id": 299870064,
#           "id_str": "299870064",
#           "indices": [
#             0,
#             9
#           ]
#         }
#       ],
#       "urls": []
#     },
#     "source": "<a href=\"https://www.sprinklr.com\" rel=\"nofollow\">Sprinklr</a>",
#     "in_reply_to_status_id": 1333362859192049665,
#     "in_reply_to_status_id_str": "1333362859192049665",
#     "in_reply_to_user_id": 299870064,
#     "in_reply_to_user_id_str": "299870064",
#     "in_reply_to_screen_name": "OVANASIL",
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "es"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "FFFFFF",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "profile_background_tile": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/953320896101412864/UdE5mfkP_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/953320896101412864/UdE5mfkP_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/415859364/1516124378",
#   "profile_link_color": "FF8400",
#   "profile_sidebar_border_color": "FFFFFF",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
# }

# %%
#obtener followers de un usuario
data = api.followers(screen_name = 'nike') #en la data anterior hemos visto que nike tiene 8millones de usuarios
#.followers() nos devuelve todo el grupo de usuarios y lo obtengo como un arreglo conteniendo elementos de tipo USER
print(len(data))
#pq me devuelve una "arreglo" de longitud 20 si hay 8mm de usuarios?
#muchas apis devuelve la info de forma paginada, en grupos
#como arrelgo que es, para verlo tengo que iterar sobre el arreglo
#for user in data:
  #print json.dumps(user._json, ident = 2)
# Out:
# 20

# %%
#pero tweepy tiene una "classe" implementada para no preocuparnos de la paginación tweepy.Cursor()
#tweepy.Cursor() -> podré obtener los items que yo quiera, sin tope de paginacion de lo que quiera, followers, likes, etc
#tweepy.Cursor(api.followers,) -> li 1ro que recibe es cuál es el método que no estoy llamando
#tweepy.Cursor(api.followers,) -> le paso el método "api.followers()", no la llamada al método "api.followers"
#tweepy.Cursor(api.followers, screen_name = "nike") le paso en nombre del usuario que estamos mirando
#tweepy.Cursor(api.followers, screen_name = "nike").items(100) -> le digo el limite de items que quiero obtener
#ahora si i sí, todo esto lo tengo que iterar
for user in tweepy.Cursor(api.followers, screen_name = "nike").items(1): #le digo sólo de un usuario
  print (json.dumps(user._json, indent = 4))
# Out:
# {
#     "id": 1371871814461366286,
#     "id_str": "1371871814461366286",
#     "name": "Artem Shabelnikov",
#     "screen_name": "ArtemShabelnik2",
#     "location": "\u041a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440, \u0420\u043e\u0441\u0441\u0438\u044f",
#     "description": "",
#     "url": null,
#     "entities": {
#         "description": {
#             "urls": []
#         }
#     },
#     "protected": false,
#     "followers_count": 1,
#     "friends_count": 34,
#     "listed_count": 0,
#     "created_at": "Tue Mar 16 17:12:47 +0000 2021",
#     "favourites_count": 0,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "verified": false,
#     "statuses_count": 4,
#     "lang": null,
#     "status": {
#         "created_at": "Fri May 14 18:11:30 +0000 2021",
#         "id": 1393267744154525698,
#         "id_str": "1393267744154525698",
#         "text": "https://t.co/bZ8zH7OzAL",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1393267739297452041,
#                     "id_str": "1393267739297452041",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/E1XhoIXWEAkH0xB.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/E1XhoIXWEAkH0xB.jpg",
#                     "url": "https://t.co/bZ8zH7OzAL",
#                     "display_url": "pic.twitter.com/bZ8zH7OzAL",
#                     "expanded_url": "https://twitter.com/ArtemShabelnik2/status/1393267744154525698/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1393267739297452041,
#                     "id_str": "1393267739297452041",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/E1XhoIXWEAkH0xB.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/E1XhoIXWEAkH0xB.jpg",
#                     "url": "https://t.co/bZ8zH7OzAL",
#                     "display_url": "pic.twitter.com/bZ8zH7OzAL",
#                     "expanded_url": "https://twitter.com/ArtemShabelnik2/status/1393267744154525698/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": {
#             "id": "b9e8625d029c7f29",
#             "url": "https://api.twitter.com/1.1/geo/id/b9e8625d029c7f29.json",
#             "place_type": "admin",
#             "name": "\u0413\u043e\u0440\u044f\u0447\u0438\u0439 \u041a\u043b\u044e\u0447",
#             "full_name": "\u0413\u043e\u0440\u044f\u0447\u0438\u0439 \u041a\u043b\u044e\u0447, \u0420\u043e\u0441\u0441\u0438\u044f",
#             "country_code": "RU",
#             "country": "Russia",
#             "contained_within": [],
#             "bounding_box": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             38.878,
#                             44.3814
#                         ],
#                         [
#                             39.609,
#                             44.3814
#                         ],
#                         [
#                             39.609,
#                             44.8511
#                         ],
#                         [
#                             38.878,
#                             44.8511
#                         ]
#                     ]
#                 ]
#             },
#             "attributes": {}
#         },
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "und"
#     },
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": null,
#     "profile_background_image_url_https": null,
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1371872295141134337/JtxLpphQ_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1371872295141134337/JtxLpphQ_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1371871814461366286/1615915629",
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "has_extended_profile": true,
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": false,
#     "live_following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "muting": false,
#     "blocking": false,
#     "blocked_by": false,
#     "translator_type": "none",
#     "withheld_in_countries": []
# }

# %%
#VAMOS A VER A QUIEN SIGUE NIKE 
#obtener friends/followeers de un usuario utilizando Cursor()
for user in tweepy.Cursor(api.friends, screen_name = "nike").items(1): #le digo sólo de un usuario
  print (json.dumps(user._json, indent = 4))
# Out:
# {
#     "id": 23151437,
#     "id_str": "23151437",
#     "name": "Kevin Hart",
#     "screen_name": "KevinHart4real",
#     "location": "Philly/LA",
#     "description": "My name is Kevin Hart and I WORK HARD!!! That pretty much sums me up!!! Everybody Wants To Be Famous But Nobody Wants To Do The Work",
#     "url": "https://t.co/QEAXjYK4eK",
#     "entities": {
#         "url": {
#             "urls": [
#                 {
#                     "url": "https://t.co/QEAXjYK4eK",
#                     "expanded_url": "http://bit.ly/kevinhartapplol",
#                     "display_url": "bit.ly/kevinhartapplol",
#                     "indices": [
#                         0,
#                         23
#                     ]
#                 }
#             ]
#         },
#         "description": {
#             "urls": []
#         }
#     },
#     "protected": false,
#     "followers_count": 36600608,
#     "friends_count": 555,
#     "listed_count": 22091,
#     "created_at": "Sat Mar 07 02:02:31 +0000 2009",
#     "favourites_count": 112,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "verified": true,
#     "statuses_count": 39917,
#     "lang": null,
#     "status": {
#         "created_at": "Mon Nov 30 06:07:10 +0000 2020",
#         "id": 1333291462029504512,
#         "id_str": "1333291462029504512",
#         "text": "What is happening on the set of #ColdasBalls4!!!? We got the ice boys mopping in the tubs, @IsaiahMustafa sneaking\u2026 https://t.co/NPKnF95IUB",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "ColdasBalls4",
#                     "indices": [
#                         32,
#                         45
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "isaiahmustafa",
#                     "name": "Isaiah Mustafa",
#                     "id": 112962217,
#                     "id_str": "112962217",
#                     "indices": [
#                         91,
#                         105
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/NPKnF95IUB",
#                     "expanded_url": "https://twitter.com/i/web/status/1333291462029504512",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         116,
#                         139
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 13,
#         "favorite_count": 326,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": true,
#         "lang": "en"
#     },
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": true,
#     "profile_background_color": "131516",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#     "profile_background_tile": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/839198522385793025/jPENEMJT_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/839198522385793025/jPENEMJT_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/23151437/1604934064",
#     "profile_link_color": "009999",
#     "profile_sidebar_border_color": "EEEEEE",
#     "profile_sidebar_fill_color": "EFEFEF",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "has_extended_profile": true,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "live_following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "muting": false,
#     "blocking": false,
#     "blocked_by": false,
#     "translator_type": "none"
# }

# %%
#OBTENER UN TIMELIME de un usuario, son todos los tweets que ha hecho un usuario en su perfil
#tweet_mode= longitud del parámetro que voy a obtener. (máx twitter 260 carácters)
#tweet_mode= "extended" -> si quiero todo
for tweet in tweepy.Cursor(api.user_timeline, 
                          screen_name = "nike", 
                          tweet_mode= "extended").items(1): #le digo sólo de un usuario
  print (json.dumps(tweet._json, indent = 4))
# Out:
# {
#     "created_at": "Mon Jul 12 07:16:19 +0000 2021",
#     "id": 1414483743859957761,
#     "id_str": "1414483743859957761",
#     "full_text": "@lukas_wiemers Hi Lukas, we're sorry to hear you're having issues using this promo code! If you contact our Support Team at +49 (0) 6995206453 or via chat, they'll be happy to help you out \ud83d\udc4d You can reach us on weekdays from 9.00-21.00, or on Saturdays from 9.00-18.00.",
#     "truncated": false,
#     "display_text_range": [
#         0,
#         269
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "lukas_wiemers",
#                 "name": "Lukas Wiemers",
#                 "id": 1007965181559889921,
#                 "id_str": "1007965181559889921",
#                 "indices": [
#                     0,
#                     14
#                 ]
#             }
#         ],
#         "urls": []
#     },
#     "source": "<a href=\"https://www.sprinklr.com\" rel=\"nofollow\">Sprinklr</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": 1007965181559889921,
#     "in_reply_to_user_id_str": "1007965181559889921",
#     "in_reply_to_screen_name": "lukas_wiemers",
#     "user": {
#         "id": 415859364,
#         "id_str": "415859364",
#         "name": "Nike",
#         "screen_name": "Nike",
#         "location": "Beaverton, Oregon",
#         "description": "#BlackLivesMatter and #StopAsianHate",
#         "url": "https://t.co/RBhnlkkzPV",
#         "entities": {
#             "url": {
#                 "urls": [
#                     {
#                         "url": "https://t.co/RBhnlkkzPV",
#                         "expanded_url": "http://nike.com",
#                         "display_url": "nike.com",
#                         "indices": [
#                             0,
#                             23
#                         ]
#                     }
#                 ]
#             },
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 8584360,
#         "friends_count": 118,
#         "listed_count": 11004,
#         "created_at": "Fri Nov 18 22:31:18 +0000 2011",
#         "favourites_count": 6958,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "verified": true,
#         "statuses_count": 37179,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/953320896101412864/UdE5mfkP_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/953320896101412864/UdE5mfkP_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/415859364/1516124378",
#         "profile_link_color": "FF8400",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 1,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
# }

# %%
#BUSCAR TWEETS
#hay muchos parámetros para la búsqueda, uno de ellos el "q"
# q = "nos permite búsqueda por texto" 

for tweet in tweepy.Cursor(api.search, 
                           q = "mundial de clubes",
                           tweet_mode= "extended").items(1): #le digo sólo de un usuario
  #print (json.dumps(tweet._json, indent = 4))
  #es largo, ahorro tinta
# Out:
#   File "<ipython-input-28-f9424c617ac0>", line 9
#     #es largo, ahorro tinta
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
#puedo transformar el "tweet" en un diccionario "._json"
#puedo acceder a sus keys, por ejemplo su "full_text"
#así me evito mucho texto que quizás no deseo

for tweet in tweepy.Cursor(api.search,                        #itera dentro de la api. buscando
                           q = "mundial de clubes",           #la expresion "mundial de clubes"
                           tweet_mode= "extended").items(10): ##tweet_mode= longitud del tweet "extendet:todo"
  print(tweet._json["full_text"])
# Out:
# RT @Corinthians: ACABOOOOOU! ACABOU! ACABOU! CORINTHIANS, BICAMPEÃO MUNDIAL DE CLUBES! O BANDO DE LOUCOS É O DONO DO MUNDO!
# @FRShitposting También tendrías menos alcance, muchos llegamos con los momazos del mundial de clubes. Estás a nada de ser tan famoso como el taquesabrozo.
# @RayadoIng @DAuri3007 @TigresOficial El pedo es este...
#
# Mundial de clubes &gt; liga mx &gt; Femenil &gt; Conca = leagues cup = campeon de campeones
#
# Y en todas estas super cogido 😁
# @7Gdzin @VitoorBrito @futebol_info Eu nao..So repassei o que a Fifa disse diversas vezes. Inclusive no seu encarte oficial de apresentação dos clubes no Mundial de 2020 em 20 idiomas diferentes
#
# Abs
# RT @laoctavasports: NO SIRVE DE NADA🏆❌
#
# En entrevista con @fantasmasuarez, Luis Miguel Salvador habló respecto a los beneficios de la Copa…
# @CeboIinhaaa A Globo passou Eurocopa por causa da perda da copa América. A Globo compra competições, séries, filmes e transmite do jeito que ela quiser só para tirar a audiência dos outros canais.
# Vide o mundial de clubes que eles só transmitem a semifinal e (se o brasileiro passar) a final
# RT @karinhinca: Corinthians 1 x 0 Chelsea - Melhores Momentos (HD - 720p) Final Mundial de Clubes 2012 https://t.co/a3WcVk4H6A
# RT @karinhinca: Corinthians 1 x 0 Chelsea - Melhores Momentos (HD - 720p) Final Mundial de Clubes 2012 https://t.co/a3WcVk4H6A
# RT @karinhinca: Corinthians 1 x 0 Chelsea - Melhores Momentos (HD - 720p) Final Mundial de Clubes 2012 https://t.co/a3WcVk4H6A
# @Maverick_Turbo Vampeta tem copa américa E copa do Mundo
#
# além disso tem mundial de clubes, brasileiro, campeonato baiano e goiano
#
# o debate já tinha acabado a muito tempo
